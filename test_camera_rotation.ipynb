# %%
import sys
import time
sys.path.append('/home/pi/project_demo/lib')
from McLumk_Wheel_Sports import (bot, move_forward, move_backward, move_left,
                                 move_right, rotate_left, rotate_right, stop_robot)
# Servo 1 : gauche/droite (0-180), servo 2 : haut/bas (0-110)
for angle in (45, 135, 90):
    bot.Ctrl_Servo(1, angle)
    time.sleep(0.6)
for angle in (30, 100, 90):
    bot.Ctrl_Servo(2, angle)
    time.sleep(0.6)
