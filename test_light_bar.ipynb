# %%
import sys
sys.path.append('/home/pi/project_demo/lib')

import time;
from Raspbot_Lib import Raspbot
from McLumk_Wheel_Sports import *

bot = Raspbot()
bot.Ctrl_WQ2812_ALL(1,4)

# %%
bot.Ctrl_WQ2812_ALL(0,0)
del bot
